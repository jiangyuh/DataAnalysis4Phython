# %% [markdown]
# ### Question One

# %%
L=[]
preL=list(range(1,500))
for x in preL:
    if(x%3==0 and x%7==0):
        L.append(x)
print("1.")
print(L)
print("2.")
print("the mean is")
total=0
for y in L:
    total=total+y
print(total/len(L))
print("25th, 50th, 75th is")
print(L[(len(L)+1)//4-1])
print(L[len(L)//2])
print(L[(len(L)+1)*3//4-1])
# Out:
# 1.
# [21, 42, 63, 84, 105, 126, 147, 168, 189, 210, 231, 252, 273, 294, 315, 336, 357, 378, 399, 420, 441, 462, 483]
# 2.
# the mean is
# 252.0
# 25th, 50th, 75th is
# 126
# 252
# 378

# %% [markdown]
# ### Question 2

# %%
print("1.")
from string import *
def countWords(s):
    w=s.split()
    return (len(w)) 

filename=open("ques2.txt",'r') #open an file in reading mode
total=0
for line in filename:
    total=total + countWords(line)
print(total)
filename.close()
# Out:
# 1.
# 309

# %%
print("2.")

def mode(l):
        count_dict={};
        for i in l:
            if i in count_dict:
                count_dict[i]+=1;
            else:
                count_dict[i]=1;
        max_appear=0
        for v in count_dict.values():
            if v>max_appear:
                max_appear=v;
        if max_appear==1:
            return;
        mode_list=[];
        for k,v in count_dict.items():
            if v==max_appear:
                mode_list.append(k);
        return mode_list;

filename=open("ques2.txt",'r')
l=filename.readline()
wl=l.split()
wordlist=[]
for x in wl:
    wordlist.append(len(x))   

count=0
for y in wordlist:
    count=count+y
print("The average is:")
print(count/len(wordlist))
print("The median is:")
wordlist=sorted(wordlist)
print(wordlist[len(wordlist)//2])
print("the mode is")
print(mode(wordlist))
filename.close()
# Out:
# 2.
# The average is:
# 5.618122977346278
# The median is:
# 5
# the mode is
# [2]

# %% [markdown]
# ### Question 3

# %%
print("1.")
import os
import random
files = os.listdir("jsons")
count=0
dict={}
for item in files:
    item=item.replace('.json','')
    for txt in open('jsons/' + item +'.json','r') :
        if "Unknown" in txt:
            count= count +1
            dict[item]=1;
        else:
            dict[item]=0;
print("the number of unknown user:")
print(count)  
print("2.")
random.sample(dict.items(), 5)
# Out:
# 1.
# the number of unknown user:
# 877
# 2.
# [('W3ZYJvUQ1BMucs2', 1),
#  ('G0mjg96A1A4z1p5', 0),
#  ('wBrAJrh61AfAeB5', 1),
#  ('g3Wxlzr91BMLLW2', 1),
#  ('QqfwcL4Y1Bnvm05', 0)]

# %% [markdown]
# ### Question 4

# %%
print("1.")
import os
import json
import re
files = os.listdir("jsons")
d={}
for item in files:
    item=item.replace('.json','')
    for txt in open('jsons/' + item +'.json','r') :
        txt= re.sub(r"(,?)(\w+?)\s*?:", r"\1'\2':", txt)
        txt= txt.replace("'", "\"")
        d[item]=json.loads(txt)

subd={}
for item in files:
    first=0
    third=0
    dd={"first":0,"third":0}
    item=item.replace('.json','')
    if "retargetingSegments" in d[item].keys():
        for y in d[item]["retargetingSegments"]:
            for (key, value) in y.items():
                if key=="segmentUid" and value.startswith("0"):
                    first=first+1
                if key=="segmentUid" and value.startswith("1"):
                    third=third+1
    dd["first"]=first
    dd["third"]=third
    subd[item]=dd
print(subd)
# Out:
# 1.
# ...
